# %%
links = '''https://www.instagram.com/iuliia_germany
https://www.instagram.com/taxelite.de
https://www.instagram.com/jura_ganz_einfach
https://www.instagram.com/lada.kolchugina
https://www.instagram.com/tot.samiy.arturchik
https://www.instagram.com/finanzen.sovet
https://www.instagram.com/khitraya.bake
https://www.instagram.com/kofman.finanzen
https://www.instagram.com/wot_trainings
https://www.instagram.com/ann.lesic
https://www.instagram.com/katebodrovaa
https://www.instagram.com/alexa.germany
https://www.instagram.com/jurikine_germany
https://www.instagram.com/sdk_akademie
https://www.instagram.com/natalia_reimer_gutsch
https://www.instagram.com/aust_finance
https://www.instagram.com/mishabur.help
https://www.instagram.com/maria___germany
https://www.instagram.com/mast.consulting
https://www.instagram.com/advokathilfe.de
https://www.instagram.com/startainstitute
https://www.instagram.com/nataliya_bystrushkina
https://www.instagram.com/germany.club
https://www.instagram.com/irinasteuern
https://www.instagram.com/kommunikant.berlin
https://www.instagram.com/mariafinanzen
https://www.instagram.com/dr.yuliya.tsaryk
https://www.instagram.com/marketolog_de
https://www.instagram.com/danilova.career
https://www.instagram.com/andreasmaljarov
https://www.instagram.com/germanyfinance_nuernberg_inna
https://www.instagram.com/mygermanjob
https://www.instagram.com/steuerberaterin_kathi
https://www.instagram.com/scheiermann_marina
https://www.instagram.com/breitmannprojects
https://www.instagram.com/doc_shakhnaz
https://www.instagram.com/finanzen.pro
https://www.instagram.com/advokat_yudashkina
https://www.instagram.com/mamagermany.de
https://www.instagram.com/garik_news
https://www.instagram.com/lapkovska.finanzcoach
https://www.instagram.com/vladislava_de
https://www.instagram.com/svetlana.franck
https://www.instagram.com/na.stoianova
https://www.instagram.com/polya.sunny
https://www.instagram.com/olyapro.online
https://www.instagram.com/steuerberater_de_lilia_riffel
https://www.instagram.com/bobkova.nataliia
https://www.instagram.com/hilfe.ukr.de
https://www.instagram.com/varivoda.de
https://www.instagram.com/pilschikov
https://www.instagram.com/alusha.life
https://www.instagram.com/deutsch_formal
https://www.instagram.com/effiside.ua
https://www.instagram.com/inge_laukert
https://www.instagram.com/engels.ira
https://www.instagram.com/finansy_v_zasade
https://www.instagram.com/finanzen.askarov
https://www.instagram.com/buchhaltung_onlineakademie
https://www.instagram.com/stb.reschke.de
https://www.instagram.com/angelina__chernysh
https://www.instagram.com/finanzen.coach
https://www.instagram.com/ivanna_scheiw
https://www.instagram.com/advokat_vogel
https://www.instagram.com/finanzen.feldbusch
https://www.instagram.com/dittmarcoaching
https://www.instagram.com/finanzen.germany
https://www.instagram.com/margarita_friebus
https://www.instagram.com/juliawischke
https://www.instagram.com/german.upgrade
https://www.instagram.com/lila_bilevska
https://www.instagram.com/yevgeniya.yeskova
https://www.instagram.com/sozialrechtlerin_on_tour
https://www.instagram.com/dta.akademie
https://www.instagram.com/elina.anerkennung.germany
https://www.instagram.com/radio_masha
https://www.instagram.com/ioksart
https://www.instagram.com/alina_mardarovskaya
https://www.instagram.com/amelli_julia
https://www.instagram.com/aittr.de
https://www.instagram.com/herr_iz_sibiri
https://www.instagram.com/danilchenko.doc
https://www.instagram.com/bayern_finanzen
https://www.instagram.com/wir.helfen42
https://www.instagram.com/lena_reisen.de
https://www.instagram.com/de.nina.de
https://www.instagram.com/nalogi_germanii
https://www.instagram.com/nalogi_v_germanii
https://www.instagram.com/mary_mua42
https://www.instagram.com/kb_finanzen
https://www.instagram.com/anastasia_germany_de
https://www.instagram.com/dimka_plushka
https://www.instagram.com/rechtsanwaeltin.denninger
https://www.instagram.com/kristina_intraclass
https://www.instagram.com/mpu_mogilevskaia
https://www.instagram.com/businessladiesacademy
https://www.instagram.com/getaway.company
https://www.instagram.com/ex_mukminova_
https://www.instagram.com/nataliya.kudelya.de
https://www.instagram.com/alena_in_deutschland
https://www.instagram.com/ulyana_germany
https://www.instagram.com/kuhn_advo
https://www.instagram.com/maria_emigration
https://www.instagram.com/bnb.bizonclub
https://www.instagram.com/inessa_huller
https://www.instagram.com/natalya.symonova
https://www.instagram.com/shef.kristina
https://www.instagram.com/marinabilze
https://www.instagram.com/viki.victoriia
https://www.instagram.com/intermigro
https://www.instagram.com/mavista_work
https://www.instagram.com/expatfinanceguide.de
https://www.instagram.com/oksana_kharaman
https://www.instagram.com/katja.weht
https://www.instagram.com/iriski.de
https://www.instagram.com/finber.de
https://www.instagram.com/alena_dailygermany
https://www.instagram.com/kak_ja_stala_frau
https://www.instagram.com/_leratan
https://www.instagram.com/pcs_coaching_berlin
https://www.instagram.com/rostislav.rautstein
https://www.instagram.com/elenasteuer.de
https://www.instagram.com/stacypregnantdiary
https://www.instagram.com/business_coach_deutschland
https://www.instagram.com/zhena_kazaha
https://www.instagram.com/steuerberater_karacoban
https://www.instagram.com/angelika_falkov
https://www.instagram.com/germany.expert
https://www.instagram.com/antimakler
https://www.instagram.com/mila_lerner
https://www.instagram.com/schatzi5551
https://www.instagram.com/morlang_consulting
https://www.instagram.com/ordnungskoenigin
https://www.instagram.com/pugatschow.kapital.grup
https://www.instagram.com/godusseldorf
https://www.instagram.com/viktorija.knazeva
https://www.instagram.com/fraufilippova
https://www.instagram.com/german.genie
https://www.instagram.com/geissregina_
https://www.instagram.com/gruenderschule
https://www.instagram.com/finanzen.krutyanskiy
https://www.instagram.com/strraus
https://www.instagram.com/ksy.mova
https://www.instagram.com/frau_iz_sibiri
https://www.instagram.com/ksenia_demianova
https://www.instagram.com/fspzusammen
https://www.instagram.com/juristgermanii
https://www.instagram.com/kotova.de
https://www.instagram.com/mariia_mkf
https://www.instagram.com/lena_germany_new
https://www.instagram.com/deutsch_mit_bozena_korn
https://www.instagram.com/lisa.seidmann
https://www.instagram.com/frau_demidova
https://www.instagram.com/deutschtrend.ua
https://www.instagram.com/ddevochka_tanya
https://www.instagram.com/inga_lamouroux
https://www.instagram.com/garik_scharit
https://www.instagram.com/xenia_hl
https://www.instagram.com/100_deutscher
https://www.instagram.com/tani.zhuravka
https://www.instagram.com/advokat_kukharenko
https://www.instagram.com/advokat_kuschnir
https://www.instagram.com/salvageeee
https://www.instagram.com/rechtsanwaeltin.fichmann
https://www.instagram.com/mutti_bunti
https://www.instagram.com/finanzen.thiede
https://www.instagram.com/vi_hanke
https://www.instagram.com/mila_artiushenko
https://www.instagram.com/deutsch.misha
https://www.instagram.com/lebyodka_doc
https://www.instagram.com/bertt8
https://www.instagram.com/annavivendi
https://www.instagram.com/boiko.und.partner
https://www.instagram.com/germanjob.knowhow
https://www.instagram.com/olga.podatki.de
https://www.instagram.com/finance.guide.europe
https://www.instagram.com/ladycats.germany
https://www.instagram.com/elza.travels
https://www.instagram.com/oh.mylem
https://www.instagram.com/arina_germany
https://www.instagram.com/kati_dusseldorf
https://www.instagram.com/itcareerhub
https://www.instagram.com/invest2go
https://www.instagram.com/dashabenz
https://www.instagram.com/irynaberlin.de
https://www.instagram.com/anastasiia_bdnrk
https://www.instagram.com/tanya_from_kharkiv
https://www.instagram.com/mishaburnews
https://www.instagram.com/anako.vg
https://www.instagram.com/nizza_nikka
https://www.instagram.com/d.kdzh
https://www.instagram.com/mari_odessitka
https://www.instagram.com/podrugi.germany
https://www.instagram.com/iryna_talavyria
https://www.instagram.com/germany.time
https://www.instagram.com/masha_watermelon_
https://www.instagram.com/mishaburcom
https://www.instagram.com/nemusli
https://www.instagram.com/karisha_kaa
https://www.instagram.com/podslushano.de'''

# %%
import re
from collections import Counter

# Входной список ссылок
# links = '''https://www.instagram.com/findgoodsongs?igsh=OHczNm1rczd6d3pv
# https://www.instagram.com/themusicfeeds?igsh=bmNqYmtycDJ1YnU3
# https://www.instagram.com/muzicpeaces?igsh=MXdzN3I4cXF2dDRsdw==
# https://www.instagram.com/unexpected.songs?igsh=b3kyM3M2Y2h6NDRx
# https://www.instagram.com/itsjmaine?igsh=enh3enVtbGxweHJ5
# https://www.instagram.com/rapmusic?igsh=MXVpZm1pcXRrbWx1Nw==
# https://www.instagram.com/reel/DFR3cy9NgqZ/?igsh=cGZsbWhuejlpNjlp
# https://www.tiktok.com/@dailydoseraps?_t=ZM-8tWcSYNAQa5&_r=1
# https://vm.tiktok.com/ZMkV6kSS9/
# https://vm.tiktok.com/ZMkV6FUNd/
# '''

# Instagram usernames extraction
try:
    # Подсчет количества входящих ссылок Instagram
    instagram_links = [line for line in links.strip().split('\n') if 'instagram.com' in line]
    total_instagram_links = len(instagram_links)

    # Извлечение usernames Instagram, исключая видео-ссылки
    instagram_usernames = []
    instagram_video_links = []
    for line in instagram_links:
        if "instagram.com/reel/" in line or "instagram.com/p/" in line:
            instagram_video_links.append(line)
        else:
            match = re.search(r'(?:https?://(?:www\.)?instagram\.com/)([\w\.]+)', line)
            if match:
                instagram_usernames.append(match.group(1))

    # Подсчет повторений Instagram
    instagram_username_counts = Counter(instagram_usernames)

    # Вывод всех извлеченных usernames Instagram
    #print("\nВсе извлеченные usernames Instagram:")
    # for user in instagram_usernames:
    #     print(user)

    # Вывод повторяющихся с количеством Instagram
    print("\nПовторяющиеся usernames Instagram и количество повторений:")
    found_instagram_repeat = False
    for user, count in instagram_username_counts.items():
        if count > 1:
            print(f"{user}: {count}")
            found_instagram_repeat = True
    if not found_instagram_repeat:
        print("Нет повторяющихся usernames Instagram")

    # Уникальные usernames Instagram (без дубликатов)
    unique_instagram_usernames = list(instagram_username_counts.keys())
    print("\nВсе уникальные usernames Instagram (без дубликатов):")
    print("\n".join(unique_instagram_usernames))

    # Вывод метрик Instagram
    print(f"\nКоличество входящих ссылок Instagram: {total_instagram_links}")
    print(f"Количество уникальных usernames Instagram: {len(unique_instagram_usernames)}")

    # Вывод ссылок на видео Instagram
    print("\nСсылки на видео Instagram:")
    if instagram_video_links:
        for video in instagram_video_links:
            print(video)
    else:
        print("Нет ссылок на видео Instagram")

except Exception as e:
    print(f"Ошибка Instagram: {e}")

# TikTok usernames extraction с фильтрацией видео
try:
    # Списки для записей
    tiktok_usernames = []
    tiktok_video_links = []
    
    # Подсчет количества входящих ссылок TikTok
    tiktok_links = [line for line in links.strip().split('\n') if 'tiktok.com' in line]
    total_tiktok_links = len(tiktok_links)
    
    # Обход каждой TikTok-ссылки
    for line in tiktok_links:
        # Если ссылка содержит "vm.tiktok.com", то это видео
        if "vm.tiktok.com" in line:
            tiktok_video_links.append(line)
            continue

        # Попытка извлечения username из ссылки вида "https://www.tiktok.com/@username..."
        match = re.search(r'(?:https?://(?:www\.)?tiktok\.com/@)([\w\.]+)', line)
        if match:
            username = match.group(1)
            # Если username равен "reel" или "p", то считаем, что это видео
            if username in ('reel', 'p'):
                tiktok_video_links.append(line)
            else:
                tiktok_usernames.append(username)
    
    # Подсчет повторений TikTok usernames
    tiktok_username_counts = Counter(tiktok_usernames)
    
    # Вывод всех извлеченных usernames TikTok
    #print("\nВсе извлеченные usernames TikTok (без video-ссылок):")
    # for user in tiktok_usernames:
    #     print(user)
    
    # Вывод повторяющихся usernames TikTok, если такие есть
    print("\nПовторяющиеся usernames TikTok и количество повторений:")
    found_tiktok_repeat = False
    for user, count in tiktok_username_counts.items():
        if count > 1:
            print(f"{user}: {count}")
            found_tiktok_repeat = True
    if not found_tiktok_repeat:
        print("Нет повторяющихся usernames TikTok")
    
    # Уникальные usernames TikTok (без дубликатов)
    unique_tiktok_usernames = list(tiktok_username_counts.keys())
    print("\nВсе уникальные usernames TikTok (без дубликатов):")
    print("\n".join(unique_tiktok_usernames))
    
    # Вывод метрик TikTok для usernames
    print(f"\nКоличество входящих ссылок TikTok: {total_tiktok_links}")
    print(f"Количество уникальных usernames TikTok: {len(unique_tiktok_usernames)}")
    
    # Вывод ссылок на видео (TikTok video-ссылки)
    print("\nСсылки на видео TikTok:")
    if tiktok_video_links:
        for video in tiktok_video_links:
            print(video)
    else:
        print("Нет ссылок на видео TikTok")
        
except Exception as e:
    print(f"Ошибка TikTok: {e}")
# Out:
# Повторяющиеся usernames Instagram и количество повторений:
# Нет повторяющихся usernames Instagram
#
# Все уникальные usernames Instagram (без дубликатов):
# iuliia_germany
# taxelite.de
# jura_ganz_einfach
# lada.kolchugina
# tot.samiy.arturchik
# finanzen.sovet
# khitraya.bake
# kofman.finanzen
# wot_trainings
# ann.lesic
# katebodrovaa
# alexa.germany
# jurikine_germany
# sdk_akademie
# natalia_reimer_gutsch
# aust_finance
# mishabur.help
# maria___germany
# mast.consulting
# advokathilfe.de
# startainstitute
# nataliya_bystrushkina
# germany.club
# irinasteuern
# kommunikant.berlin
# mariafinanzen
# dr.yuliya.tsaryk
# marketolog_de
# danilova.career
# andreasmaljarov
# germanyfinance_nuernberg_inna
# mygermanjob
# steuerberaterin_kathi
# scheiermann_marina
# breitmannprojects
# doc_shakhnaz
# finanzen.pro
# advokat_yudashkina
# mamagermany.de
# garik_news
# lapkovska.finanzcoach
# vladislava_de
# svetlana.franck
# na.stoianova
# polya.sunny
# olyapro.online
# ...
