# %%
links = '''1. https://www.instagram.com/yananutritionist?igsh=YjczaG5tcW5wOG9r
2. https://www.instagram.com/nutrition_eva?igsh=MWY0YTN3d2lzcnlsOA==
3. https://www.instagram.com/krista_nutrition?igsh=MXNsZnNlejJmcDFrYQ==
4. https://www.instagram.com/ikatia_nutrition?igsh=MTZ4azhqaWU1a2ptYg==
5. https://www.instagram.com/nutritionist_maks?igsh=ZTd5Y2NqYnZoMDE2
6. https://www.instagram.com/july.nutrition?igsh=MTI0eGdvbHlmOTQxcw==
7. https://www.instagram.com/radna.nutrition?igsh=MTY0eXNoNnpuM3Z6Mw==
8. https://www.instagram.com/nutritionist_olesia?igsh=ZmZ2b3F3bXcxY212
9. https://www.instagram.com/nutrition.by.alsu?igsh=M2VyeWNjOTV6Mms=
10. https://www.instagram.com/precisionnutrition?igsh=MWN1MW8yd3lmM2xyZQ==
11. https://www.instagram.com/alla.nutrition?igsh=MXg5bDQ2YnBrcjU0bg==
12. https://www.instagram.com/real.life.nutritionist?igsh=MWhrYmlya3poY3dlcA==
13. https://www.instagram.com/nutrition_x_?igsh=ZTVqa3UwdWhvdWNr
14. https://www.instagram.com/alina___nutrition?igsh=cXYyZHU4MjB6czZz
15. https://www.instagram.com/period.nutritionist?igsh=cXh6Nzl0MmU0d2c4
16. https://www.instagram.com/nutritionschool?igsh=ZzBhOW4zN2NteXN0
17. https://www.instagram.com/sofi_pro_nutrition?igsh=MW1xbDZ6NHZxM2tydw==
18. https://www.instagram.com/nutrition_tips._?igsh=MW5zZWl3MGM1MXV5dg==
19. https://www.instagram.com/nutritiontipsss?igsh=MWJobDZiZTdzMGtpbQ==
20. https://www.instagram.com/nutritiontips.ig?igsh=MWhxZXZncjY3YmJ6Mw==
21. https://www.instagram.com/healthytips.bymargarida?igsh=endhMGo0cGMxcDBj
22. https://www.instagram.com/nutrition_facts_org?igsh=ZnYwYjY1cm5tODZl
23. https://www.instagram.com/nutritionfactsz?igsh=cThxdm14djV6eG8y
24. https://www.instagram.com/nutrition_factsz?igsh=MXQ5eGtleDU1M2pp
25. https://www.instagram.com/wellness.genetics?igsh=YzhqOHJ4NzZwcXY=
26. https://www.instagram.com/anaastas?igsh=YnFocGVkZ3Q1b2dw
27. https://www.instagram.com/_olga_kononovich_?igsh=MWc5MzVoc3ZlMGd5NQ==
28. https://www.instagram.com/marina.biohack?igsh=Zm91Njc1NHQ0NWl0
29. https://www.instagram.com/nastarostina?igsh=MTAybW1hbG1paW9seA==
30. https://www.instagram.com/__alenami__?igsh=OGpjZG9ha3JoMjJn
31. https://www.instagram.com/vikatere_food?igsh=eDMwd2J1eWFocHA0
32. https://www.instagram.com/nutrition_eva?igsh=MWY0YTN3d2lzcnlsOA==
33. https://www.instagram.com/vladysyaa?igsh=MThic256emwwMHYxcA==
34. https://www.instagram.com/ahims_a?igsh=MXU5NWljeDBlYXNnYg==
35. https://www.instagram.com/kildyash_ovaa?igsh=a2h3cjQ5a3kya3Y=
36. https://www.instagram.com/zhigulskaya_marina?igsh=end6Z2t3bXMxdHA=
37. https://www.instagram.com/alesya.fitchina?igsh=OGlyMTRhYTdwZjJu
38. https://www.instagram.com/pique_7sheva?igsh=cmhxM29pdnE4aDBn
39. https://www.instagram.com/nikishinanatalia_?igsh=MWxwaDlyejNlazZveg==
40. https://www.instagram.com/emilinss_nutri?igsh=MTBtY2tvYTV2eXNhMA==
41. https://www.instagram.com/jenny.foodcoach?igsh=aDlpZWEwaXdvZ2gw
42. https://www.instagram.com/efima_pharm?igsh=MXY4cWV4ZXhwOHFtYQ==
43. https://www.instagram.com/amelyrain.eco?igsh=ZDl6aW5rZXF6aXh0
44. https://www.instagram.com/chipolina_dina?igsh=OTk5NnRpOHpxbHRl
45. https://www.instagram.com/alenkamaslova?igsh=MWc3ZmNyODE0emhmMA==
46. https://www.instagram.com/radna.nutrition?igsh=MTY0eXNoNnpuM3Z6Mw==
47. https://www.instagram.com/dr.ayupova.t?igsh=Zmhla3ZmM3NoeDQx
48. https://www.instagram.com/marrojka?igsh=MWhvZTM0NXh1bzV4dg==
49. https://www.instagram.com/nastasia.one?igsh=ZGh0enFlZGhqb2Z2
50. https://www.instagram.com/academy_pro_zdorovje?igsh=MW96NjQxbHkxeXl6
51. https://www.instagram.com/marina_propitanie?igsh=dHA3NDB1d3I3NTV1
https://www.instagram.com/ycombinator?igsh=bjg2emt6eGg4d3A4
https://www.instagram.com/techcrunch?igsh=Yjh1aWw4NGVrNGwy
https://www.instagram.com/foundr?igsh=MThlNWt3bXlkMGc0bw==
https://www.instagram.com/entrepreneur?igsh=MXJzOHk2dWlubmo5Mw==
https://www.instagram.com/harvard_business_review?igsh=MWtoeTM0MjNtbGZnbA==
https://www.instagram.com/oskar_hartmann?igsh=dGFpMzRoeW9xcmtv
https://www.instagram.com/oskar_hartmann?igsh=dGFpMzRoeW9xcmtv
https://www.instagram.com/artemkey_new?igsh=MXR0dzN2eWFoNTJwOQ==
https://www.instagram.com/lkv_srg?igsh=MTk5NzZwdTR5a2hhZg==

https://www.instagram.com/volkovafinance?igsh=MWF4YXZubXR6YWtyeQ==

https://www.instagram.com/nata_smart.life?igsh=OHZ6Y3l3NDluZXY4

https://www.instagram.com/devushka.s.dengami?igsh=MTI3dXdrZDFqNmRyag==

https://www.instagram.com/raevazakon?igsh=MW82YTk1Ym83ZG0zdg=='''

# %%
import re
from collections import Counter

# Входной список ссылок
# links = '''https://www.instagram.com/findgoodsongs?igsh=OHczNm1rczd6d3pv
# https://www.instagram.com/themusicfeeds?igsh=bmNqYmtycDJ1YnU3
# https://www.instagram.com/muzicpeaces?igsh=MXdzN3I4cXF2dDRsdw==
# https://www.instagram.com/unexpected.songs?igsh=b3kyM3M2Y2h6NDRx
# https://www.instagram.com/itsjmaine?igsh=enh3enVtbGxweHJ5
# https://www.instagram.com/rapmusic?igsh=MXVpZm1pcXRrbWx1Nw==
# https://www.instagram.com/reel/DFR3cy9NgqZ/?igsh=cGZsbWhuejlpNjlp
# https://www.tiktok.com/@dailydoseraps?_t=ZM-8tWcSYNAQa5&_r=1
# https://vm.tiktok.com/ZMkV6kSS9/
# https://vm.tiktok.com/ZMkV6FUNd/
# '''

# Instagram usernames extraction
try:
    # Подсчет количества входящих ссылок Instagram
    instagram_links = [line for line in links.strip().split('\n') if 'instagram.com' in line]
    total_instagram_links = len(instagram_links)

    # Извлечение usernames Instagram, исключая видео-ссылки
    instagram_usernames = []
    instagram_video_links = []
    for line in instagram_links:
        if "instagram.com/reel/" in line or "instagram.com/p/" in line:
            instagram_video_links.append(line)
        else:
            match = re.search(r'(?:https?://(?:www\.)?instagram\.com/)([\w\.]+)', line)
            if match:
                instagram_usernames.append(match.group(1))

    # Подсчет повторений Instagram
    instagram_username_counts = Counter(instagram_usernames)

    # Вывод всех извлеченных usernames Instagram
    #print("\nВсе извлеченные usernames Instagram:")
    # for user in instagram_usernames:
    #     print(user)

    # Вывод повторяющихся с количеством Instagram
    print("\nПовторяющиеся usernames Instagram и количество повторений:")
    found_instagram_repeat = False
    for user, count in instagram_username_counts.items():
        if count > 1:
            print(f"{user}: {count}")
            found_instagram_repeat = True
    if not found_instagram_repeat:
        print("Нет повторяющихся usernames Instagram")

    # Уникальные usernames Instagram (без дубликатов)
    unique_instagram_usernames = list(instagram_username_counts.keys())
    print("\nВсе уникальные usernames Instagram (без дубликатов):")
    print("\n".join(unique_instagram_usernames))

    # Вывод метрик Instagram
    print(f"\nКоличество входящих ссылок Instagram: {total_instagram_links}")
    print(f"Количество уникальных usernames Instagram: {len(unique_instagram_usernames)}")

    # Вывод ссылок на видео Instagram
    print("\nСсылки на видео Instagram:")
    if instagram_video_links:
        for video in instagram_video_links:
            print(video)
    else:
        print("Нет ссылок на видео Instagram")

except Exception as e:
    print(f"Ошибка Instagram: {e}")

# TikTok usernames extraction с фильтрацией видео
try:
    # Списки для записей
    tiktok_usernames = []
    tiktok_video_links = []
    
    # Подсчет количества входящих ссылок TikTok
    tiktok_links = [line for line in links.strip().split('\n') if 'tiktok.com' in line]
    total_tiktok_links = len(tiktok_links)
    
    # Обход каждой TikTok-ссылки
    for line in tiktok_links:
        # Если ссылка содержит "vm.tiktok.com", то это видео
        if "vm.tiktok.com" in line:
            tiktok_video_links.append(line)
            continue

        # Попытка извлечения username из ссылки вида "https://www.tiktok.com/@username..."
        match = re.search(r'(?:https?://(?:www\.)?tiktok\.com/@)([\w\.]+)', line)
        if match:
            username = match.group(1)
            # Если username равен "reel" или "p", то считаем, что это видео
            if username in ('reel', 'p'):
                tiktok_video_links.append(line)
            else:
                tiktok_usernames.append(username)
    
    # Подсчет повторений TikTok usernames
    tiktok_username_counts = Counter(tiktok_usernames)
    
    # Вывод всех извлеченных usernames TikTok
    #print("\nВсе извлеченные usernames TikTok (без video-ссылок):")
    # for user in tiktok_usernames:
    #     print(user)
    
    # Вывод повторяющихся usernames TikTok, если такие есть
    print("\nПовторяющиеся usernames TikTok и количество повторений:")
    found_tiktok_repeat = False
    for user, count in tiktok_username_counts.items():
        if count > 1:
            print(f"{user}: {count}")
            found_tiktok_repeat = True
    if not found_tiktok_repeat:
        print("Нет повторяющихся usernames TikTok")
    
    # Уникальные usernames TikTok (без дубликатов)
    unique_tiktok_usernames = list(tiktok_username_counts.keys())
    print("\nВсе уникальные usernames TikTok (без дубликатов):")
    print("\n".join(unique_tiktok_usernames))
    
    # Вывод метрик TikTok для usernames
    print(f"\nКоличество входящих ссылок TikTok: {total_tiktok_links}")
    print(f"Количество уникальных usernames TikTok: {len(unique_tiktok_usernames)}")
    
    # Вывод ссылок на видео (TikTok video-ссылки)
    print("\nСсылки на видео TikTok:")
    if tiktok_video_links:
        for video in tiktok_video_links:
            print(video)
    else:
        print("Нет ссылок на видео TikTok")
        
except Exception as e:
    print(f"Ошибка TikTok: {e}")
# Out:
# Повторяющиеся usernames Instagram и количество повторений:
# nutrition_eva: 2
# radna.nutrition: 2
# oskar_hartmann: 2
#
# Все уникальные usernames Instagram (без дубликатов):
# yananutritionist
# nutrition_eva
# krista_nutrition
# ikatia_nutrition
# nutritionist_maks
# july.nutrition
# radna.nutrition
# nutritionist_olesia
# nutrition.by.alsu
# precisionnutrition
# alla.nutrition
# real.life.nutritionist
# nutrition_x_
# alina___nutrition
# period.nutritionist
# nutritionschool
# sofi_pro_nutrition
# nutrition_tips._
# nutritiontipsss
# nutritiontips.ig
# healthytips.bymargarida
# nutrition_facts_org
# nutritionfactsz
# nutrition_factsz
# wellness.genetics
# anaastas
# _olga_kononovich_
# marina.biohack
# nastarostina
# __alenami__
# vikatere_food
# vladysyaa
# ahims_a
# kildyash_ovaa
# zhigulskaya_marina
# alesya.fitchina
# pique_7sheva
# nikishinanatalia_
# emilinss_nutri
# jenny.foodcoach
# efima_pharm
# amelyrain.eco
# chipolina_dina
# alenkamaslova
# dr.ayupova.t
# marrojka
# ...
