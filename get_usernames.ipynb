# %%
links = '''https://www.instagram.com/psicologofrancisco1?igsh=Nzlxb3FwMnVubHcx
https://www.instagram.com/brandonmentesclaras?igsh=M20yYnBmMjVyY2J4
https://www.instagram.com/analucia_mente_cuerpo?igsh=MjFhdXJncTJyZjI=
https://www.instagram.com/sara_mentesana?igsh=NGhqMWlxbjlua3J0
https://www.instagram.com/santibarreiro__?igsh=MWxyNHFicXdxMm1oaA==
https://www.instagram.com/asolers?igsh=amp4NGtsZzRkcnl4
https://www.instagram.com/alealvarezpsi?igsh=czh0YXR5eDA2dGo3
https://www.instagram.com/psicologataniaruizz?igsh=dTFlMXh3ZDF5Zmph
https://www.instagram.com/berstamateas?igsh=cnFlZjhtNThnbnNz
https://www.instagram.com/psimariaeduarda2?igsh=djE4bnRhZm4yaHRl
https://www.instagram.com/holistic.therapist.gayathri?igsh=MTJnZWowZDk5NGlhcg==
https://www.instagram.com/avance_total?igsh=bzFkYzVubzluNmJj
https://www.instagram.com/ch.hunabku?igsh=d2s3Z216OGd0cjc4
https://www.instagram.com/elementos.energeticos?igsh=MXNjY2loa2FlOGs5MA==
https://www.instagram.com/consejosdebuda?igsh=ZnJoajFieWNpN2Z6
https://www.instagram.com/meditationsecrets?igsh=MXF4NzM1d2Q3b3c4dQ==
https://www.instagram.com/abymendozasana?igsh=MTl2dTZnMG10YWZjag==
https://www.instagram.com/thezensamurai?igsh=Y25jb3Z6anJ5ZWZj
https://www.instagram.com/shashankayur?igsh=NXA1emN0MHQ0dnls
https://www.instagram.com/sique.soma?igsh=MTh0enBmMjBtaXZ5eg==
https://www.instagram.com/salud.poderosa?igsh=MWhyZnp6dWZ4Y3Fjdg==
https://www.instagram.com/alexeisabella?igsh=MXJsM2U3dzR6NzZhcA==
https://www.instagram.com/dr.konstantine.bisbikos?igsh=c2FpN3YyMjVzaWxz
https://www.instagram.com/corymuscara?igsh=NWtxcXFtYXJzaHFy
https://www.instagram.com/analucia_mente_cuerpo?igsh=MjFhdXJncTJyZjI=
https://www.instagram.com/menteeplenaa?igsh=MWUyMXh4ajJ6cXEybg==
https://www.instagram.com/rama_escuela?igsh=MXJtcTRrMzNpMjhtYw==
https://www.instagram.com/menteeplenaa?igsh=MWUyMXh4ajJ6cXEybg==
https://www.instagram.com/refugio.psico?igsh=MXc0cmlzMXF5NXR4ag==
https://www.instagram.com/psicologiaxnicolas
https://www.instagram.com/vibood.psicologia
https://www.instagram.com/psicologofrancisco1
https://www.instagram.com/analucia_mente_cuerpo
https://www.instagram.com/asolers
https://www.instagram.com/getsoundrx
https://www.instagram.com/jimcurtis1
https://www.instagram.com/alealvarezpsi
https://www.instagram.com/faridieck
https://www.instagram.com/brandonmentesclaras
https://www.instagram.com/lamarinchen_oficial
https://www.instagram.com/sara_mentesana
https://www.instagram.com/psicologia_persuasiva
https://www.instagram.com/psicologia.integrativa
https://www.instagram.com/turefugiopsicologia
https://www.instagram.com/ivanapsicologia
https://www.instagram.com/beatanxiety.me
https://www.instagram.com/niki_din
https://www.instagram.com/drjoedispenzaru
https://www.instagram.com/julia.yatchenia
https://www.instagram.com/daily_breathing
https://www.instagram.com/soothing_breathe
https://www.instagram.com/careerheights
https://www.instagram.com/psico.healers
https://www.instagram.com/psicologiaporlasdudas
https://www.instagram.com/thejordisegues
https://www.instagram.com/santibarreiro__
https://www.instagram.com/joaojucapsi'''

# %%
import re
from collections import Counter

# Входной список ссылок
# links = '''https://www.instagram.com/findgoodsongs?igsh=OHczNm1rczd6d3pv
# https://www.instagram.com/themusicfeeds?igsh=bmNqYmtycDJ1YnU3
# https://www.instagram.com/muzicpeaces?igsh=MXdzN3I4cXF2dDRsdw==
# https://www.instagram.com/unexpected.songs?igsh=b3kyM3M2Y2h6NDRx
# https://www.instagram.com/itsjmaine?igsh=enh3enVtbGxweHJ5
# https://www.instagram.com/rapmusic?igsh=MXVpZm1pcXRrbWx1Nw==
# https://www.instagram.com/reel/DFR3cy9NgqZ/?igsh=cGZsbWhuejlpNjlp
# https://www.tiktok.com/@dailydoseraps?_t=ZM-8tWcSYNAQa5&_r=1
# https://vm.tiktok.com/ZMkV6kSS9/
# https://vm.tiktok.com/ZMkV6FUNd/
# '''

# Instagram usernames extraction
try:
    # Подсчет количества входящих ссылок Instagram
    instagram_links = [line for line in links.strip().split('\n') if 'instagram.com' in line]
    total_instagram_links = len(instagram_links)

    # Извлечение usernames Instagram, исключая видео-ссылки
    instagram_usernames = []
    instagram_video_links = []
    for line in instagram_links:
        if "instagram.com/reel/" in line or "instagram.com/p/" in line:
            instagram_video_links.append(line)
        else:
            match = re.search(r'(?:https?://(?:www\.)?instagram\.com/)([\w\.]+)', line)
            if match:
                instagram_usernames.append(match.group(1))

    # Подсчет повторений Instagram
    instagram_username_counts = Counter(instagram_usernames)

    # Вывод всех извлеченных usernames Instagram
    #print("\nВсе извлеченные usernames Instagram:")
    # for user in instagram_usernames:
    #     print(user)

    # Вывод повторяющихся с количеством Instagram
    print("\nПовторяющиеся usernames Instagram и количество повторений:")
    found_instagram_repeat = False
    for user, count in instagram_username_counts.items():
        if count > 1:
            print(f"{user}: {count}")
            found_instagram_repeat = True
    if not found_instagram_repeat:
        print("Нет повторяющихся usernames Instagram")

    # Уникальные usernames Instagram (без дубликатов)
    unique_instagram_usernames = list(instagram_username_counts.keys())
    print("\nВсе уникальные usernames Instagram (без дубликатов):")
    print("\n".join(unique_instagram_usernames))

    # Вывод метрик Instagram
    print(f"\nКоличество входящих ссылок Instagram: {total_instagram_links}")
    print(f"Количество уникальных usernames Instagram: {len(unique_instagram_usernames)}")

    # Вывод ссылок на видео Instagram
    print("\nСсылки на видео Instagram:")
    if instagram_video_links:
        for video in instagram_video_links:
            print(video)
    else:
        print("Нет ссылок на видео Instagram")

except Exception as e:
    print(f"Ошибка Instagram: {e}")

# TikTok usernames extraction с фильтрацией видео
try:
    # Списки для записей
    tiktok_usernames = []
    tiktok_video_links = []
    
    # Подсчет количества входящих ссылок TikTok
    tiktok_links = [line for line in links.strip().split('\n') if 'tiktok.com' in line]
    total_tiktok_links = len(tiktok_links)
    
    # Обход каждой TikTok-ссылки
    for line in tiktok_links:
        # Если ссылка содержит "vm.tiktok.com", то это видео
        if "vm.tiktok.com" in line:
            tiktok_video_links.append(line)
            continue

        # Попытка извлечения username из ссылки вида "https://www.tiktok.com/@username..."
        match = re.search(r'(?:https?://(?:www\.)?tiktok\.com/@)([\w\.]+)', line)
        if match:
            username = match.group(1)
            # Если username равен "reel" или "p", то считаем, что это видео
            if username in ('reel', 'p'):
                tiktok_video_links.append(line)
            else:
                tiktok_usernames.append(username)
    
    # Подсчет повторений TikTok usernames
    tiktok_username_counts = Counter(tiktok_usernames)
    
    # Вывод всех извлеченных usernames TikTok
    #print("\nВсе извлеченные usernames TikTok (без video-ссылок):")
    # for user in tiktok_usernames:
    #     print(user)
    
    # Вывод повторяющихся usernames TikTok, если такие есть
    print("\nПовторяющиеся usernames TikTok и количество повторений:")
    found_tiktok_repeat = False
    for user, count in tiktok_username_counts.items():
        if count > 1:
            print(f"{user}: {count}")
            found_tiktok_repeat = True
    if not found_tiktok_repeat:
        print("Нет повторяющихся usernames TikTok")
    
    # Уникальные usernames TikTok (без дубликатов)
    unique_tiktok_usernames = list(tiktok_username_counts.keys())
    print("\nВсе уникальные usernames TikTok (без дубликатов):")
    print("\n".join(unique_tiktok_usernames))
    
    # Вывод метрик TikTok для usernames
    print(f"\nКоличество входящих ссылок TikTok: {total_tiktok_links}")
    print(f"Количество уникальных usernames TikTok: {len(unique_tiktok_usernames)}")
    
    # Вывод ссылок на видео (TikTok video-ссылки)
    print("\nСсылки на видео TikTok:")
    if tiktok_video_links:
        for video in tiktok_video_links:
            print(video)
    else:
        print("Нет ссылок на видео TikTok")
        
except Exception as e:
    print(f"Ошибка TikTok: {e}")
# Out:
# Повторяющиеся usernames Instagram и количество повторений:
# psicologofrancisco1: 2
# brandonmentesclaras: 2
# analucia_mente_cuerpo: 3
# sara_mentesana: 2
# santibarreiro__: 2
# asolers: 2
# alealvarezpsi: 2
# menteeplenaa: 2
#
# Все уникальные usernames Instagram (без дубликатов):
# psicologofrancisco1
# brandonmentesclaras
# analucia_mente_cuerpo
# sara_mentesana
# santibarreiro__
# asolers
# alealvarezpsi
# psicologataniaruizz
# berstamateas
# psimariaeduarda2
# holistic.therapist.gayathri
# avance_total
# ch.hunabku
# elementos.energeticos
# consejosdebuda
# meditationsecrets
# abymendozasana
# thezensamurai
# shashankayur
# sique.soma
# salud.poderosa
# alexeisabella
# dr.konstantine.bisbikos
# corymuscara
# menteeplenaa
# rama_escuela
# refugio.psico
# psicologiaxnicolas
# vibood.psicologia
# getsoundrx
# jimcurtis1
# faridieck
# lamarinchen_oficial
# psicologia_persuasiva
# psicologia.integrativa
# turefugiopsicologia
# ivanapsicologia
# beatanxiety.me
# niki_din
# drjoedispenzaru
# julia.yatchenia
# daily_breathing
# soothing_breathe
# careerheights
# psico.healers
# psicologiaporlasdudas
# thejordisegues
# joaojucapsi
#
# Количество входящих ссылок Instagram: 57
# Количество уникальных usernames Instagram: 48
#
# Ссылки на видео Instagram:
# Нет ссылок на видео Instagram
#
# Повторяющиеся usernames TikTok и количество повторений:
# Нет повторяющихся usernames TikTok
#
# Все уникальные usernames TikTok (без дубликатов):
#
#
# Количество входящих ссылок TikTok: 0
# Количество уникальных usernames TikTok: 0
#
# Ссылки на видео TikTok:
# Нет ссылок на видео TikTok
